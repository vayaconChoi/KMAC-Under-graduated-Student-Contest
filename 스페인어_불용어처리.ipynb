-Cuidado: Aplicar medicina y vender las heridas

■ Ojo Rojo
-Examinar: Buscar gérmenes bajo un microscopio
-Cuidado: Curar con gotas para los ojos

■ Problema de la Piel
-Examinar: Quitar la suciedad de la herida
-Cuidados: Desinfectar, coser y vendar la herida

■ Alergias
-Examinar: Examinar el tipo de alergias alimentarias
-Cuidados: Dar al paciente medicación para ayudar con la alergia.

■ Ataque de Abejas
-Examinar: Retire la colmena de la cabeza
-Cuidado: Limpie la miel y trate la picadura de abeja

■ Telarañas y Arañas
-Examinar: Quitar arañas y telarañas del brazo
-Cuidados: Desinfectar y tratar heridas. Usa medicina también

■ Polvo de Mariposa
-Examinar: Limpiar el polvo de mariposa
-Cuidado: Atrae a las mariposas con flores

■ Control de Salud
-¡Hágase un chequeo médico! Examine sus ojos y oídos también

■ ¡Emergencia!
- ¡Cocobí! Viaja en la ambulancia. ¡Un paciente está pegado a un pulpo y otro paciente tiene una emergencia cardíaca!

¡El juego ofrece 14 tipos diferentes de tratamiento médico y tres juegos de tratamiento de emergencia! Es genial para la educación. Aprenda sobre huesos rotos, resfriados, lesiones, alergias y más. ¡Descubre la importancia de la salud, y protege tu cuerpo de enfermedades!
...
'''

# Función para limpiar y extraer palabras clave
def extraer_keywords(texto):
    # Tokenizar el texto
    palabras = word_tokenize(texto.lower())

    # Obtener las stopwords en español
    stop_words = set(stopwords.words('spanish'))

    # Eliminar stopwords y palabras que no son alfabéticas
    keywords = [palabra for palabra in palabras if palabra not in stop_words and palabra.isalpha()]

    return keywords

# Aplicar la función al texto
palabras_clave = extraer_keywords(texto)
print(palabras_clave)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %%
palabras_clave
# Out:
# ['enfermo',
#  'hospital',
#  'cocobí',
#  'coco',
#  'lobi',
#  'ayudarán',
#  'juegos',
#  'atención',
#  'médica',
#  'curar',
#  'secreción',
#  'nasal',
#  'fiebre',
#  'estómago',
#  'usa',
#  'estetoscopio',
#  'usa',
#  'inyección',
#  'encuentra',
#  'virus',
#  'microscopio',
#  'tratar',
#  'vendar',
#  'huesos',
#  'lesionados',
#  'limpiar',
#  'curar',
#  'oídos',
#  'hinchados',
#  'limpiar',
#  'secreción',
#  'nasal',
#  'retire',
#  'espinas',
#  'desinfecte',
#  'herida',
#  'cura',
#  'ojos',
#  'rojos',
#  'elige',
#  'par',
#  'gafas',
#  'desinfectar',
#  'vendar',
#  'heridas',
#  'cuidado',
#  'alergias',
#  'alimentarias',
#  'paciente',
#  'atrapado',
#  'colmena',
#  'ahuyentar',
#  'abejas',
#  'atrapa',
#  'arañas',
#  'quita',
#  'telarañas',
#  'brazo',
#  'atrae',
#  'mariposas',
#  'flores',
#  'salud',
#  'controla',
#  'salud',
#  'retire',
#  'tentáculos',
#  'pulpo',
#  'rescatar',
#  'pacientes',
#  'fuego',
#  'hacer',
#  'rcp',
#  'corazón',
# ...
